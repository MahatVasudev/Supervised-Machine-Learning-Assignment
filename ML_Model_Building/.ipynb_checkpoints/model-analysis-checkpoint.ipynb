# %%
from datasets.fire_dataset import val_dataset, train_dataset, test_dataset

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt 
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
from models.CONVLSTM import ConvLSTM, ConvLSTM2Layers

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # Model Visualization

# %%
model = ConvLSTM().to(device=device)
model.load_state_dict(torch.load("saved_models/ConvLSTM_3v_45_checkpoint.pt")["model"])
# Out:
# <All keys matched successfully>

# %%
min_lat, max_lat = -55.0, 82.0
min_lon, max_lon = -179.0, 179.5

# %%
def show_heatmap_over_n_days(generated_map: np.ndarray | torch.Tensor,  
                 coords: list, figure_size: list = [10, 5], color_map: str= "hot", roll: int | None = None):
    assert len(generated_map.shape) == 4
    assert isinstance(coords, list) or isinstance(coords, tuple) or coords == None  
    
    # dimensions to show
    min_lat, max_lat = coords[0]
    min_lon, max_lon = coords[1]
        
    # prepare map
    n_lat = generated_map.shape[2]
    n_lon = generated_map.shape[3]
    
    # horizontal shift
    if roll != None:
        generated_map = np.roll(generated_map, shift=roll, axis=-1)
    
    lat_edges = np.linspace(min_lat, max_lat, n_lat + 1)
    lon_edges = np.linspace(min_lon, max_lon, n_lon + 1)

    lat_mask = (lat_edges >= min_lat) & (lat_edges <= max_lat) 
    lon_mask = (lon_edges >= min_lon) & (lon_edges <= max_lon)

    lat_indices = np.where(lat_mask)[0]
    lon_indices = np.where(lon_mask)[0]

    if len(lat_indices) == 0 or len(lon_indices) == 0:
        raise ValueError("Coordinate bounds do not intersect with data grid")
    
    lat_slice = slice(lat_indices[0], lat_indices[-1]+1)
    lon_slice = slice(lon_indices[0], lon_indices[-1]+1)

    generated_map_zoomed = generated_map[:, :, lat_slice, lon_slice]
    lat_zoomed = lat_edges[lat_slice]
    lon_zoomed = lon_edges[lon_slice]

    lon_grid, lat_grid = np.meshgrid(lon_zoomed, lat_zoomed)
    
    fig = plt.figure(figsize=figure_size)
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines(resolution='10m', color='gray', linewidth=0.6)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)
    ax.set_extent([min_lon, max_lon, min_lat, max_lat], crs=ccrs.PlateCarree())

    pcm = ax.pcolormesh(
        lon_grid, lat_grid,
        generated_map_zoomed[0, 0],
        cmap=color_map,
        shading='auto',
        alpha=0.7,vmin=-0.1, vmax= 2.5,           
        transform=ccrs.PlateCarree()
    )
    plt.colorbar(pcm, ax=ax, label='Predicted Value')
    plt.show()

    return generated_map_zoomed, (lat_zoomed, lon_zoomed), pcm, fig

# %%
def make_predictions(X, n_days: int) -> np.ndarray:
    X_input = X.to(device)  # Move input tensor to the same device as the model
    predictions = []
    model.eval()
    with torch.no_grad():
        for day in range(n_days):
            Y_pred = model(X_input)
            predictions.append(Y_pred.cpu().numpy())
            X_input = torch.cat([X_input[:, 1:], Y_pred.unsqueeze(1)], dim=1)
    return np.concatenate(predictions, axis=0)

# %%
X, Y = train_dataset[1]

# %%
X.unsqueeze(0).dtype
# Out:
# torch.float32

# %%
criterion = nn.MSELoss()

# %%
y_pred_np = make_predictions(X[:3].unsqueeze(0), 4)

y_pred_tensor = torch.tensor(y_pred_np, device=device, dtype=torch.float32)

y_true_tensor = Y.unsqueeze(0).to(device).float()

loss = criterion(y_pred_tensor, y_true_tensor)
# Out:
# /home/clyde/anaconda3/envs/self-driving-cars/lib/python3.12/site-packages/torch/nn/modules/loss.py:610: UserWarning: Using a target size (torch.Size([1, 1, 269, 687])) that is different to the input size (torch.Size([4, 1, 269, 687])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
def update(frame, generated_map_zoomed, pcm, title=None):
   
    data = generated_map_zoomed[frame, 0]
    pcm.set_array(data.ravel())  
    
    if title is not None:
        title.set_text(f"Day {frame + 1} Prediction")
        return [pcm, title]
    else:
        return [pcm]

# %%
true_map_zoomed
# Out:
# array([[[[-0.11446705, -0.11446705, -0.11446705, ..., -0.11446705,
#           -0.11446705, -0.11446705],
#          [-0.11446705, -0.11446705, -0.11446705, ..., -0.11446705,
#           -0.11446705, -0.11446705],
#          [-0.11446705, -0.11446705, -0.11446705, ..., -0.11446705,
#           -0.11446705, -0.11446705],
#          ...,
#          [-0.11446705, -0.11446705, -0.11446705, ..., -0.11446705,
#           -0.11446705, -0.11446705],
#          [-0.11446705, -0.11446705, -0.11446705, ..., -0.11446705,
#           -0.11446705, -0.11446705],
#          [-0.11446705, -0.11446705, -0.11446705, ..., -0.11446705,
#           -0.11446705, -0.11446705]]]], dtype=float32)

# %%
true_map_zoomed, (true_lat_zoomed, true_lon_zoomed), tpcm, tAx = show_heatmap_over_n_days(X[3:], 
                                                                                          coords=[(min_lat, max_lat), (min_lon, max_lon)],
                                                                                         roll=5)

# %%
pred_map_zoomed, (pred_lat_zoomed, pred_lon_zoomed), ppcm, pAx = show_heatmap_over_n_days(y_pred_np, 
                                                                                          coords=[(min_lat, max_lat), (min_lon, max_lon)],
                                                                                         roll=5)

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# after setting up your plot:

anim = FuncAnimation(
    tAx, update, 
    frames=true_map_zoomed.shape[0], 
    fargs=(true_map_zoomed, tpcm),
    interval=500, blit=False
)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgfd9e1d8b36944a9f978362f844a7abd5">
#   <div class="anim-controls">
#     <input id="_anim_sliderfd9e1d8b36944a9f978362f844a7abd5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animfd9e1d8b36944a9f978362f844a7abd5.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animfd9e1d8b36944a9f978362f844a7abd5.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animfd9e1d8b36944a9f978362f844a7abd5.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animfd9e1d8b36944a9f978362f844a7abd5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animfd9e1d8b36944a9f978362f844a7abd5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animfd9e1d8b36944a9f978362f844a7abd5.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animfd9e1d8b36944a9f978362f844a7abd5.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animfd9e1d8b36944a9f978362f844a7abd5.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animfd9e1d8b36944a9f978362f844a7abd5.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animfd9e1d8b36944a9f978362f844a7abd5.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectfd9e1d8b36944a9f978362f844a7abd5"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_fd9e1d8b36944a9f978362f844a7abd5"
#              >
#       <label for="_anim_radio1_fd9e1d8b36944a9f978362f844a7abd5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_fd9e1d8b36944a9f978362f844a7abd5"
#              checked>
#       <label for="_anim_radio2_fd9e1d8b36944a9f978362f844a7abd5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_fd9e1d8b36944a9f978362f844a7abd5"
#              >
#       <label for="_anim_radio3_fd9e1d8b36944a9f978362f844a7abd5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgfd9e1d8b36944a9f978362f844a7abd5";
#     var slider_id = "_anim_sliderfd9e1d8b36944a9f978362f844a7abd5";
#     var loop_select_id = "_anim_loop_selectfd9e1d8b36944a9f978362f844a7abd5";
#     var frames = new Array(4);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjcsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvTLEjVAAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQABAABJRE

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# after setting up your plot:

anim = FuncAnimation(
    pAx, update, 
    frames=pred_map_zoomed.shape[0], 
    fargs=(pred_map_zoomed, ppcm),
    interval=500, blit=False
)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img63c96bec58ec41a09dc1aee0f7916b52">
#   <div class="anim-controls">
#     <input id="_anim_slider63c96bec58ec41a09dc1aee0f7916b52" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim63c96bec58ec41a09dc1aee0f7916b52.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim63c96bec58ec41a09dc1aee0f7916b52.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select63c96bec58ec41a09dc1aee0f7916b52"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_63c96bec58ec41a09dc1aee0f7916b52"
#              >
#       <label for="_anim_radio1_63c96bec58ec41a09dc1aee0f7916b52">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_63c96bec58ec41a09dc1aee0f7916b52"
#              checked>
#       <label for="_anim_radio2_63c96bec58ec41a09dc1aee0f7916b52">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_63c96bec58ec41a09dc1aee0f7916b52"
#              >
#       <label for="_anim_radio3_63c96bec58ec41a09dc1aee0f7916b52">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img63c96bec58ec41a09dc1aee0f7916b52";
#     var slider_id = "_anim_slider63c96bec58ec41a09dc1aee0f7916b52";
#     var loop_select_id = "_anim_loop_select63c96bec58ec41a09dc1aee0f7916b52";
#     var frames = new Array(4);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjcsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvTLEjVAAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQABAABJRE
